# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split

# %%
# %run preprocessing.ipynb
# %run temporal_preprocess.ipynb
# %run graph.ipynb
# Out:
# 100%|██████████| 6/6 [09:21<00:00, 93.53s/it]
#                        Feature  Importance
# 0                       ged_sb    0.109912
# 1               decay_ged_ns_1    0.093771
# 2      sptime_dist_k001_ged_ns    0.056070
# 3       splag_1_decay_ged_sb_1    0.035770
# 4      sptime_dist_k001_ged_os    0.035527
# 5           wdi_nv_agr_totl_kd    0.032515
# 6       sptime_dist_k10_ged_ns    0.026288
# 7       sptime_dist_k10_ged_os    0.026096
# 8        sptime_dist_k1_ged_ns    0.022685
# 9              spei_48_detrend    0.022117
# 10           spei1_gsm_detrend    0.018739
# 11  ged_sb_decay_12_time_since    0.018219
# 12       mov_avg_6_ged_best_sb    0.018188
# 13       mov_sum_6_ged_best_sb    0.016237
# 14                treelag_1_ns    0.014685
# 15                   ged_gte_1    0.014666
# 16                treelag_2_os    0.014348
# 17                treelag_2_ns    0.014340
# 18                treelag_1_os    0.014174
# 19             spei1_gs_prev10    0.012800
# 20      sptime_dist_k10_ged_sb    0.012221
# 21       sptime_dist_k1_ged_sb    0.012162
# 22        spei1_gs_prev10_anom    0.012088
# 23       ged_sb_tlag_1_splag_1    0.010702
# 24             tlag1_spei1_gsm    0.010079
# 25      mov_avg_12_ged_best_sb    0.009534
# 26       sptime_dist_k1_ged_os    0.009386
# 27               ged_sb_tlag_1    0.008947
# 28     sptime_dist_k001_ged_sb    0.008678
# 29      mov_sum_12_ged_best_sb    0.008515
# 30      mov_sum_36_ged_best_sb    0.008139
# 31               ged_sb_tlag_7    0.007843
# 32  spei1gsy_lowermedian_count    0.007612
# 33               ged_sb_tlag_2    0.007531
# 34           spei1_gsm_cv_anom    0.007472
# 35               ged_sb_tlag_3    0.007380
# 36      mov_avg_36_ged_best_sb    0.007113
# 37             decay_ged_sb_25    0.007060
# 38               ged_sb_tlag_4    0.007055
# 39              ged_sb_tlag_11    0.006968
# 40               ged_sb_tlag_8    0.006933
# 41               ged_sb_tlag_9    0.006891
# 42              ged_sb_tlag_12    0.006827
# 43               ged_sb_tlag_5    0.006767
# 44                treelag_1_sb    0.006735
# 45  count_moder_drought_prev10    0.006657
# 46                treelag_2_sb    0.006457
# 47              ged_sb_tlag_10    0.006446
# 48  tlag_12_harvarea_maincrops    0.006003
# 49            tlag_12_crop_sum    0.005974
# Shape of array for priogrid_gid -3.086626264365936: (80, 51)
# Shape of array for priogrid_gid -2.441018211693147: (80, 51)
# Shape of array for priogrid_gid -2.4409807699456163: (80, 51)
# Shape of array for priogrid_gid -2.4409433281980855: (80, 51)
# Shape of array for priogrid_gid -2.4141350369660657: (80, 51)
# Shape of array for priogrid_gid -2.414097595218535: (80, 51)
# Shape of array for priogrid_gid -2.4140601534710044: (80, 51)
# Shape of array for priogrid_gid -2.4140227117234736: (80, 51)
# Shape of array for priogrid_gid -2.4139852699759428: (80, 51)
# Shape of array for priogrid_gid -2.413947828228412: (80, 51)
# Shape of array for priogrid_gid -2.413910386480881: (80, 51)
# Shape of array for priogrid_gid -2.4138729447333507: (80, 51)
# Shape of array for priogrid_gid -2.41383550298582: (80, 51)
# Shape of array for priogrid_gid -2.413798061238289: (80, 51)
# Shape of array for priogrid_gid -2.413760619490758: (80, 51)
# Shape of array for priogrid_gid -2.4137231777432273: (80, 51)
# Shape of array for priogrid_gid -2.413685735995697: (80, 51)
# Shape of array for priogrid_gid -2.413648294248166: (80, 51)
# Shape of array for priogrid_gid -2.4136108525006352: (80, 51)
# Shape of array for priogrid_gid -2.4135734107531044: (80, 51)
# Shape of array for priogrid_gid -2.387176978743923: (80, 51)
# Shape of array for priogrid_gid -2.387139536996392: (80, 51)
# Shape of array for priogrid_gid -2.3871020952488613: (80, 51)
# Shape of array for priogrid_gid -2.387064653501331: (80, 51)
# Shape of array for priogrid_gid -2.3870272117538: (80, 51)
# Shape of array for priogrid_gid -2.386989770006269: (80, 51)
# Shape of array for priogrid_gid -2.3869523282587384: (80, 51)
# Shape of array for priogrid_gid -2.3869148865112075: (80, 51)
# Shape of array for priogrid_gid -2.386877444763677: (80, 51)
# Shape of array for priogrid_gid -2.3868400030161463: (80, 51)
# Shape of array for priogrid_gid -2.3868025612686155: (80, 51)
# Shape of array for priogrid_gid -2.3867651195210846: (80, 51)
# Shape of array for priogrid_gid -2.3867276777735538: (80, 51)
# Shape of array for priogrid_gid -2.3866902360260234: (80, 51)
# Shape of array for priogrid_gid -2.3866527942784925: (80, 51)
# Shape of array for priogrid_gid -2.3866153525309617: (80, 51)
# Shape of array for priogrid_gid -2.386577910783431: (80, 51)
# Shape of array for priogrid_gid -2.3865404690359: (80, 51)
# Shape of array for priogrid_gid -2.3865030272883696: (80, 51)
# Shape of array for priogrid_gid -2.360256362269311: (80, 51)
# Shape of array for priogrid_gid -2.3602189205217803: (80, 51)
# Shape of array for priogrid_gid -2.3601814787742494: (80, 51)
# Shape of array for priogrid_gid -2.3601440370267186: (80, 51)
# Shape of array for priogrid_gid -2.3601065952791878: (80, 51)
# Shape of array for priogrid_gid -2.3600691535316574: (80, 51)
# Shape of array for priogrid_gid -2.3600317117841265: (80, 51)
# Shape of array for priogrid_gid -2.3599942700365957: (80, 51)
# Shape of array for priogrid_gid -2.359956828289065: (80, 51)
# Shape of array for priogrid_gid -2.359919386541534: (80, 51)
# Shape of array for priogrid_gid -2.3598819447940036: (80, 51)
# Shape of array for priogrid_gid -2.3598445030464728: (80, 51)
# Shape of array for priogrid_gid -2.359807061298942: (80, 51)
# Shape of array for priogrid_gid -2.359769619551411: (80, 51)
# Shape of array for priogrid_gid -2.3597321778038802: (80, 51)
# Shape of array for priogrid_gid -2.35969473605635: (80, 51)
# Shape of array for priogrid_gid -2.359657294308819: (80, 51)
# Shape of array for priogrid_gid -2.359619852561288: (80, 51)
# Shape of array for priogrid_gid -2.3595824108137573: (80, 51)
# Shape of array for priogrid_gid -2.3595449690662265: (80, 51)
# Shape of array for priogrid_gid -2.359507527318696: (80, 51)
# Shape of array for priogrid_gid -2.333298304047168: (80, 51)
# Shape of array for priogrid_gid -2.3332608622996376: (80, 51)
# Shape of array for priogrid_gid -2.3332234205521067: (80, 51)
# Shape of array for priogrid_gid -2.333185978804576: (80, 51)
# Shape of array for priogrid_gid -2.333148537057045: (80, 51)
# Shape of array for priogrid_gid -2.333111095309514: (80, 51)
# Shape of array for priogrid_gid -2.333073653561984: (80, 51)
# Shape of array for priogrid_gid -2.333036211814453: (80, 51)
# Shape of array for priogrid_gid -2.332998770066922: (80, 51)
# Shape of array for priogrid_gid -2.3329613283193913: (80, 51)
# Shape of array for priogrid_gid -2.3329238865718605: (80, 51)
# Shape of array for priogrid_gid -2.33288644482433: (80, 51)
# Shape of array for priogrid_gid -2.332849003076799: (80, 51)
# Shape of array for priogrid_gid -2.3328115613292684: (80, 51)
# Shape of array for priogrid_gid -2.3327741195817375: (80, 51)
# Shape of array for priogrid_gid -2.3327366778342067: (80, 51)
# Shape of array for priogrid_gid -2.3326992360866763: (80, 51)
# Shape of array for priogrid_gid -2.3326617943391454: (80, 51)
# Shape of array for priogrid_gid -2.3326243525916146: (80, 51)
# Shape of array for priogrid_gid -2.3325869108440838: (80, 51)
# Shape of array for priogrid_gid -2.332549469096553: (80, 51)
# Shape of array for priogrid_gid -2.332512027349022: (80, 51)
# Shape of array for priogrid_gid -2.3324745856014917: (80, 51)
# Shape of array for priogrid_gid -2.3063028040774944: (80, 51)
# Shape of array for priogrid_gid -2.306265362329964: (80, 51)
# Shape of array for priogrid_gid -2.306227920582433: (80, 51)
# Shape of array for priogrid_gid -2.3061904788349024: (80, 51)
# Shape of array for priogrid_gid -2.3061530370873715: (80, 51)
# Shape of array for priogrid_gid -2.3061155953398407: (80, 51)
# Shape of array for priogrid_gid -2.3060781535923103: (80, 51)
# Shape of array for priogrid_gid -2.3060407118447794: (80, 51)
# Shape of array for priogrid_gid -2.3060032700972486: (80, 51)
# Shape of array for priogrid_gid -2.3059658283497178: (80, 51)
# Shape of array for priogrid_gid -2.305928386602187: (80, 51)
# Shape of array for priogrid_gid -2.3058909448546565: (80, 51)
# Shape of array for priogrid_gid -2.3058535031071257: (80, 51)
# Shape of array for priogrid_gid -2.305816061359595: (80, 51)
# Shape of array for priogrid_gid -2.305778619612064: (80, 51)
# Shape of array for priogrid_gid -2.305741177864533: (80, 51)
# Shape of array for priogrid_gid -2.3057037361170023: (80, 51)
# Shape of array for priogrid_gid -2.305666294369472: (80, 51)
# Shape of array for priogrid_gid -2.305628852621941: (80, 51)
# Shape of array for priogrid_gid -2.30559141087441: (80, 51)
# Shape of array for priogrid_gid -2.3055539691268794: (80, 51)
# Shape of array for priogrid_gid -2.3055165273793485: (80, 51)
# Shape of array for priogrid_gid -2.305479085631818: (80, 51)
# Shape of array for priogrid_gid -2.2793447458553517: (80, 51)
# Shape of array for priogrid_gid -2.279307304107821: (80, 51)
# Shape of array for priogrid_gid -2.2792698623602905: (80, 51)
# Shape of array for priogrid_gid -2.2792324206127597: (80, 51)
# Shape of array for priogrid_gid -2.279194978865229: (80, 51)
# Shape of array for priogrid_gid -2.279157537117698: (80, 51)
# Shape of array for priogrid_gid -2.279120095370167: (80, 51)
# Shape of array for priogrid_gid -2.2790826536226363: (80, 51)
# Shape of array for priogrid_gid -2.279045211875106: (80, 51)
# Shape of array for priogrid_gid -2.279007770127575: (80, 51)
# Shape of array for priogrid_gid -2.278970328380044: (80, 51)
# Shape of array for priogrid_gid -2.2789328866325134: (80, 51)
# Shape of array for priogrid_gid -2.2788954448849825: (80, 51)
# Shape of array for priogrid_gid -2.278858003137452: (80, 51)
# Shape of array for priogrid_gid -2.2788205613899213: (80, 51)
# Shape of array for priogrid_gid -2.2787831196423904: (80, 51)
# Shape of array for priogrid_gid -2.2787456778948596: (80, 51)
# Shape of array for priogrid_gid -2.2787082361473288: (80, 51)
# Shape of array for priogrid_gid -2.2786707943997984: (80, 51)
# Shape of array for priogrid_gid -2.2786333526522675: (80, 51)
# Shape of array for priogrid_gid -2.2785959109047367: (80, 51)
# Shape of array for priogrid_gid -2.278558469157206: (80, 51)
# Shape of array for priogrid_gid -2.278521027409675: (80, 51)
# Shape of array for priogrid_gid -2.2784835856621446: (80, 51)
# Shape of array for priogrid_gid -2.25242412938074: (80, 51)
# Shape of array for priogrid_gid -2.252386687633209: (80, 51)
# Shape of array for priogrid_gid -2.252349245885678: (80, 51)
# Shape of array for priogrid_gid -2.2523118041381474: (80, 51)
# Shape of array for priogrid_gid -2.2522743623906165: (80, 51)
# Shape of array for priogrid_gid -2.252236920643086: (80, 51)
# Shape of array for priogrid_gid -2.2521994788955553: (80, 51)
# Shape of array for priogrid_gid -2.2521620371480244: (80, 51)
# Shape of array for priogrid_gid -2.2521245954004936: (80, 51)
# Shape of array for priogrid_gid -2.2520871536529627: (80, 51)
# Shape of array for priogrid_gid -2.2520497119054323: (80, 51)
# Shape of array for priogrid_gid -2.2520122701579015: (80, 51)
# Shape of array for priogrid_gid -2.2519748284103707: (80, 51)
# Shape of array for priogrid_gid -2.25193738666284: (80, 51)
# Shape of array for priogrid_gid -2.251899944915309: (80, 51)
# Shape of array for priogrid_gid -2.2518625031677786: (80, 51)
# Shape of array for priogrid_gid -2.2518250614202477: (80, 51)
# Shape of array for priogrid_gid -2.251787619672717: (80, 51)
# Shape of array for priogrid_gid -2.251750177925186: (80, 51)
# Shape of array for priogrid_gid -2.251712736177655: (80, 51)
# Shape of array for priogrid_gid -2.251675294430125: (80, 51)
# Shape of array for priogrid_gid -2.251637852682594: (80, 51)
# Shape of array for priogrid_gid -2.251600410935063: (80, 51)
# Shape of array for priogrid_gid -2.2515629691875323: (80, 51)
# Shape of array for priogrid_gid -2.2515255274400015: (80, 51)
# Shape of array for priogrid_gid -2.251488085692471: (80, 51)
# Shape of array for priogrid_gid -2.2255035129061276: (80, 51)
# Shape of array for priogrid_gid -2.2254660711585967: (80, 51)
# Shape of array for priogrid_gid -2.2254286294110663: (80, 51)
# Shape of array for priogrid_gid -2.2253911876635355: (80, 51)
# Shape of array for priogrid_gid -2.2253537459160047: (80, 51)
# Shape of array for priogrid_gid -2.225316304168474: (80, 51)
# Shape of array for priogrid_gid -2.225278862420943: (80, 51)
# Shape of array for priogrid_gid -2.2252414206734126: (80, 51)
# Shape of array for priogrid_gid -2.2252039789258817: (80, 51)
# Shape of array for priogrid_gid -2.225166537178351: (80, 51)
# Shape of array for priogrid_gid -2.22512909543082: (80, 51)
# Shape of array for priogrid_gid -2.225091653683289: (80, 51)
# Shape of array for priogrid_gid -2.225054211935759: (80, 51)
# Shape of array for priogrid_gid -2.225016770188228: (80, 51)
# Shape of array for priogrid_gid -2.224979328440697: (80, 51)
# Shape of array for priogrid_gid -2.2249418866931663: (80, 51)
# Shape of array for priogrid_gid -2.2249044449456354: (80, 51)
# Shape of array for priogrid_gid -2.224867003198105: (80, 51)
# Shape of array for priogrid_gid -2.224829561450574: (80, 51)
# Shape of array for priogrid_gid -2.2247921197030434: (80, 51)
# Shape of array for priogrid_gid -2.2247546779555125: (80, 51)
# Shape of array for priogrid_gid -2.2247172362079817: (80, 51)
# Shape of array for priogrid_gid -2.2246797944604513: (80, 51)
# Shape of array for priogrid_gid -2.2246423527129204: (80, 51)
# Shape of array for priogrid_gid -2.2246049109653896: (80, 51)
# Shape of array for priogrid_gid -2.2245674692178588: (80, 51)
# Shape of array for priogrid_gid -2.224530027470328: (80, 51)
# Shape of array for priogrid_gid -2.2244925857227975: (80, 51)
# Shape of array for priogrid_gid -2.198545454683985: (80, 51)
# Shape of array for priogrid_gid -2.198508012936454: (80, 51)
# Shape of array for priogrid_gid -2.198470571188923: (80, 51)
# Shape of array for priogrid_gid -2.198433129441393: (80, 51)
# Shape of array for priogrid_gid -2.198395687693862: (80, 51)
# Shape of array for priogrid_gid -2.198358245946331: (80, 51)
# Shape of array for priogrid_gid -2.1983208041988003: (80, 51)
# Shape of array for priogrid_gid -2.1982833624512694: (80, 51)
# Shape of array for priogrid_gid -2.198245920703739: (80, 51)
# Shape of array for priogrid_gid -2.198208478956208: (80, 51)
# Shape of array for priogrid_gid -2.1981710372086773: (80, 51)
# Shape of array for priogrid_gid -2.1981335954611465: (80, 51)
# Shape of array for priogrid_gid -2.1980961537136157: (80, 51)
# Shape of array for priogrid_gid -2.1980587119660853: (80, 51)
# Shape of array for priogrid_gid -2.1980212702185544: (80, 51)
# Shape of array for priogrid_gid -2.1979838284710236: (80, 51)
# Shape of array for priogrid_gid -2.1979463867234927: (80, 51)
# Shape of array for priogrid_gid -2.197908944975962: (80, 51)
# Shape of array for priogrid_gid -2.1978715032284315: (80, 51)
# Shape of array for priogrid_gid -2.1978340614809007: (80, 51)
# Shape of array for priogrid_gid -2.19779661973337: (80, 51)
# Shape of array for priogrid_gid -2.197759177985839: (80, 51)
# Shape of array for priogrid_gid -2.197721736238308: (80, 51)
# Shape of array for priogrid_gid -2.1976842944907777: (80, 51)
# Shape of array for priogrid_gid -2.197646852743247: (80, 51)
# Shape of array for priogrid_gid -2.197609410995716: (80, 51)
# Shape of array for priogrid_gid -2.197571969248185: (80, 51)
# Shape of array for priogrid_gid -2.1975345275006544: (80, 51)
# Shape of array for priogrid_gid -2.171624838209373: (80, 51)
# Shape of array for priogrid_gid -2.171587396461842: (80, 51)
# Shape of array for priogrid_gid -2.1715499547143113: (80, 51)
# Shape of array for priogrid_gid -2.1715125129667805: (80, 51)
# Shape of array for priogrid_gid -2.1714750712192497: (80, 51)
# Shape of array for priogrid_gid -2.1714376294717193: (80, 51)
# Shape of array for priogrid_gid -2.1714001877241884: (80, 51)
# Shape of array for priogrid_gid -2.1713627459766576: (80, 51)
# Shape of array for priogrid_gid -2.1713253042291267: (80, 51)
# Shape of array for priogrid_gid -2.171287862481596: (80, 51)
# Shape of array for priogrid_gid -2.1712504207340655: (80, 51)
# Shape of array for priogrid_gid -2.1712129789865346: (80, 51)
# Shape of array for priogrid_gid -2.171175537239004: (80, 51)
# Shape of array for priogrid_gid -2.171138095491473: (80, 51)
# Shape of array for priogrid_gid -2.171100653743942: (80, 51)
# Shape of array for priogrid_gid -2.1710632119964117: (80, 51)
# Shape of array for priogrid_gid -2.171025770248881: (80, 51)
# Shape of array for priogrid_gid -2.17098832850135: (80, 51)
# Shape of array for priogrid_gid -2.170950886753819: (80, 51)
# Shape of array for priogrid_gid -2.1709134450062884: (80, 51)
# Shape of array for priogrid_gid -2.170876003258758: (80, 51)
# Shape of array for priogrid_gid -2.170838561511227: (80, 51)
# Shape of array for priogrid_gid -2.1708011197636963: (80, 51)
# Shape of array for priogrid_gid -2.1707636780161654: (80, 51)
# Shape of array for priogrid_gid -2.1707262362686346: (80, 51)
# Shape of array for priogrid_gid -2.170688794521104: (80, 51)
# Shape of array for priogrid_gid -2.1706513527735734: (80, 51)
# Shape of array for priogrid_gid -2.1706139110260425: (80, 51)
# Shape of array for priogrid_gid -2.1705764692785117: (80, 51)
# Shape of array for priogrid_gid -2.170539027530981: (80, 51)
# Shape of array for priogrid_gid -2.14466677998723: (80, 51)
# Shape of array for priogrid_gid -2.1446293382396995: (80, 51)
# Shape of array for priogrid_gid -2.1445918964921686: (80, 51)
# Shape of array for priogrid_gid -2.144554454744638: (80, 51)
# Shape of array for priogrid_gid -2.144517012997107: (80, 51)
# Shape of array for priogrid_gid -2.144479571249576: (80, 51)
# Shape of array for priogrid_gid -2.1444421295020457: (80, 51)
# Shape of array for priogrid_gid -2.144404687754515: (80, 51)
# Shape of array for priogrid_gid -2.144367246006984: (80, 51)
# Shape of array for priogrid_gid -2.144329804259453: (80, 51)
# Shape of array for priogrid_gid -2.1442923625119223: (80, 51)
# Shape of array for priogrid_gid -2.144254920764392: (80, 51)
# Shape of array for priogrid_gid -2.144217479016861: (80, 51)
# Shape of array for priogrid_gid -2.1441800372693303: (80, 51)
# Shape of array for priogrid_gid -2.1441425955217994: (80, 51)
# Shape of array for priogrid_gid -2.1441051537742686: (80, 51)
# Shape of array for priogrid_gid -2.144067712026738: (80, 51)
# Shape of array for priogrid_gid -2.1440302702792073: (80, 51)
# Shape of array for priogrid_gid -2.1439928285316765: (80, 51)
# Shape of array for priogrid_gid -2.1439553867841457: (80, 51)
# Shape of array for priogrid_gid -2.143917945036615: (80, 51)
# Shape of array for priogrid_gid -2.1438805032890844: (80, 51)
# Shape of array for priogrid_gid -2.1438430615415536: (80, 51)
# Shape of array for priogrid_gid -2.1438056197940227: (80, 51)
# Shape of array for priogrid_gid -2.143768178046492: (80, 51)
# Shape of array for priogrid_gid -2.143730736298961: (80, 51)
# Shape of array for priogrid_gid -2.1436932945514307: (80, 51)
# Shape of array for priogrid_gid -2.1436558528039: (80, 51)
# Shape of array for priogrid_gid -2.143618411056369: (80, 51)
# Shape of array for priogrid_gid -2.143580969308838: (80, 51)
# Shape of array for priogrid_gid -2.1435435275613073: (80, 51)
# Shape of array for priogrid_gid -2.117746163512618: (80, 51)
# Shape of array for priogrid_gid -2.117708721765087: (80, 51)
# Shape of array for priogrid_gid -2.1176712800175563: (80, 51)
# Shape of array for priogrid_gid -2.117633838270026: (80, 51)
# Shape of array for priogrid_gid -2.117596396522495: (80, 51)
# Shape of array for priogrid_gid -2.1175589547749643: (80, 51)
# Shape of array for priogrid_gid -2.1175215130274334: (80, 51)
# Shape of array for priogrid_gid -2.1174840712799026: (80, 51)
# Shape of array for priogrid_gid -2.117446629532372: (80, 51)
# Shape of array for priogrid_gid -2.1174091877848413: (80, 51)
# Shape of array for priogrid_gid -2.1173717460373105: (80, 51)
# Shape of array for priogrid_gid -2.1173343042897796: (80, 51)
# Shape of array for priogrid_gid -2.117296862542249: (80, 51)
# Shape of array for priogrid_gid -2.1172594207947184: (80, 51)
# Shape of array for priogrid_gid -2.1172219790471876: (80, 51)
# Shape of array for priogrid_gid -2.1171845372996567: (80, 51)
# Shape of array for priogrid_gid -2.117147095552126: (80, 51)
# Shape of array for priogrid_gid -2.117109653804595: (80, 51)
# Shape of array for priogrid_gid -2.1170722120570646: (80, 51)
# Shape of array for priogrid_gid -2.117034770309534: (80, 51)
# Shape of array for priogrid_gid -2.116997328562003: (80, 51)
# Shape of array for priogrid_gid -2.116959886814472: (80, 51)
# Shape of array for priogrid_gid -2.1169224450669413: (80, 51)
# Shape of array for priogrid_gid -2.116885003319411: (80, 51)
# Shape of array for priogrid_gid -2.11684756157188: (80, 51)
# Shape of array for priogrid_gid -2.116810119824349: (80, 51)
# Shape of array for priogrid_gid -2.1167726780768183: (80, 51)
# Shape of array for priogrid_gid -2.1167352363292875: (80, 51)
# Shape of array for priogrid_gid -2.116697794581757: (80, 51)
# Shape of array for priogrid_gid -2.1166603528342263: (80, 51)
# Shape of array for priogrid_gid -2.1166229110866954: (80, 51)
# Shape of array for priogrid_gid -2.1165854693391646: (80, 51)
# Shape of array for priogrid_gid -2.1165480275916337: (80, 51)
# Shape of array for priogrid_gid -2.090825547038006: (80, 51)
# Shape of array for priogrid_gid -2.0907881052904753: (80, 51)
# Shape of array for priogrid_gid -2.0907506635429445: (80, 51)
# Shape of array for priogrid_gid -2.0907132217954136: (80, 51)
# Shape of array for priogrid_gid -2.090675780047883: (80, 51)
# Shape of array for priogrid_gid -2.0906383383003524: (80, 51)
# Shape of array for priogrid_gid -2.0906008965528216: (80, 51)
# Shape of array for priogrid_gid -2.0905634548052907: (80, 51)
# Shape of array for priogrid_gid -2.09052601305776: (80, 51)
# Shape of array for priogrid_gid -2.090488571310229: (80, 51)
# Shape of array for priogrid_gid -2.0904511295626986: (80, 51)
# Shape of array for priogrid_gid -2.090413687815168: (80, 51)
# Shape of array for priogrid_gid -2.090376246067637: (80, 51)
# Shape of array for priogrid_gid -2.090338804320106: (80, 51)
# Shape of array for priogrid_gid -2.0903013625725753: (80, 51)
# Shape of array for priogrid_gid -2.090263920825045: (80, 51)
# Shape of array for priogrid_gid -2.090226479077514: (80, 51)
# Shape of array for priogrid_gid -2.090189037329983: (80, 51)
# Shape of array for priogrid_gid -2.0901515955824523: (80, 51)
# Shape of array for priogrid_gid -2.0901141538349215: (80, 51)
# Shape of array for priogrid_gid -2.090076712087391: (80, 51)
# Shape of array for priogrid_gid -2.0900392703398603: (80, 51)
# Shape of array for priogrid_gid -2.0900018285923294: (80, 51)
# Shape of array for priogrid_gid -2.0899643868447986: (80, 51)
# Shape of array for priogrid_gid -2.0899269450972677: (80, 51)
# Shape of array for priogrid_gid -2.0898895033497373: (80, 51)
# Shape of array for priogrid_gid -2.0898520616022065: (80, 51)
# Shape of array for priogrid_gid -2.0898146198546756: (80, 51)
# Shape of array for priogrid_gid -2.089777178107145: (80, 51)
# Shape of array for priogrid_gid -2.089739736359614: (80, 51)
# Shape of array for priogrid_gid -2.0897022946120836: (80, 51)
# Shape of array for priogrid_gid -2.0896648528645527: (80, 51)
# Shape of array for priogrid_gid -2.089627411117022: (80, 51)
# Shape of array for priogrid_gid -2.089589969369491: (80, 51)
# Shape of array for priogrid_gid -2.08955252762196: (80, 51)
# Shape of array for priogrid_gid -2.063904930563394: (80, 51)
# Shape of array for priogrid_gid -2.063867488815863: (80, 51)
# Shape of array for priogrid_gid -2.0638300470683326: (80, 51)
# Shape of array for priogrid_gid -2.0637926053208018: (80, 51)
# Shape of array for priogrid_gid -2.063755163573271: (80, 51)
# Shape of array for priogrid_gid -2.06371772182574: (80, 51)
# Shape of array for priogrid_gid -2.0636802800782093: (80, 51)
# Shape of array for priogrid_gid -2.063642838330679: (80, 51)
# Shape of array for priogrid_gid -2.063605396583148: (80, 51)
# Shape of array for priogrid_gid -2.063567954835617: (80, 51)
# Shape of array for priogrid_gid -2.0635305130880863: (80, 51)
# Shape of array for priogrid_gid -2.0634930713405555: (80, 51)
# Shape of array for priogrid_gid -2.063455629593025: (80, 51)
# Shape of array for priogrid_gid -2.0634181878454942: (80, 51)
# Shape of array for priogrid_gid -2.0633807460979634: (80, 51)
# Shape of array for priogrid_gid -2.0633433043504326: (80, 51)
# Shape of array for priogrid_gid -2.0633058626029017: (80, 51)
# Shape of array for priogrid_gid -2.0632684208553713: (80, 51)
# Shape of array for priogrid_gid -2.0632309791078405: (80, 51)
# Shape of array for priogrid_gid -2.0631935373603096: (80, 51)
# Shape of array for priogrid_gid -2.063156095612779: (80, 51)
# Shape of array for priogrid_gid -2.063118653865248: (80, 51)
# Shape of array for priogrid_gid -2.0630812121177176: (80, 51)
# Shape of array for priogrid_gid -2.0630437703701867: (80, 51)
# Shape of array for priogrid_gid -2.063006328622656: (80, 51)
# Shape of array for priogrid_gid -2.062968886875125: (80, 51)
# Shape of array for priogrid_gid -2.062931445127594: (80, 51)
# Shape of array for priogrid_gid -2.062894003380064: (80, 51)
# Shape of array for priogrid_gid -2.062856561632533: (80, 51)
# Shape of array for priogrid_gid -2.062819119885002: (80, 51)
# Shape of array for priogrid_gid -2.0627816781374713: (80, 51)
# Shape of array for priogrid_gid -2.0627442363899404: (80, 51)
# Shape of array for priogrid_gid -2.06270679464241: (80, 51)
# Shape of array for priogrid_gid -2.062669352894879: (80, 51)
# Shape of array for priogrid_gid -2.0626319111473483: (80, 51)
# Shape of array for priogrid_gid -2.0625944693998175: (80, 51)
# Shape of array for priogrid_gid -2.036946872341251: (80, 51)
# Shape of array for priogrid_gid -2.0369094305937203: (80, 51)
# Shape of array for priogrid_gid -2.0368719888461895: (80, 51)
# Shape of array for priogrid_gid -2.036834547098659: (80, 51)
# Shape of array for priogrid_gid -2.0367971053511282: (80, 51)
# Shape of array for priogrid_gid -2.0367596636035974: (80, 51)
# Shape of array for priogrid_gid -2.0367222218560666: (80, 51)
# Shape of array for priogrid_gid -2.0366847801085357: (80, 51)
# Shape of array for priogrid_gid -2.0366473383610053: (80, 51)
# Shape of array for priogrid_gid -2.0366098966134745: (80, 51)
# Shape of array for priogrid_gid -2.0365724548659436: (80, 51)
# Shape of array for priogrid_gid -2.036535013118413: (80, 51)
# Shape of array for priogrid_gid -2.036497571370882: (80, 51)
# Shape of array for priogrid_gid -2.0364601296233515: (80, 51)
# Shape of array for priogrid_gid -2.0364226878758207: (80, 51)
# Shape of array for priogrid_gid -2.03638524612829: (80, 51)
# Shape of array for priogrid_gid -2.036347804380759: (80, 51)
# Shape of array for priogrid_gid -2.036310362633228: (80, 51)
# Shape of array for priogrid_gid -2.036272920885698: (80, 51)
# Shape of array for priogrid_gid -2.036235479138167: (80, 51)
# Shape of array for priogrid_gid -2.036198037390636: (80, 51)
# Shape of array for priogrid_gid -2.0361605956431053: (80, 51)
# Shape of array for priogrid_gid -2.0361231538955744: (80, 51)
# Shape of array for priogrid_gid -2.036085712148044: (80, 51)
# Shape of array for priogrid_gid -2.036048270400513: (80, 51)
# Shape of array for priogrid_gid -2.0360108286529823: (80, 51)
# Shape of array for priogrid_gid -2.0359733869054515: (80, 51)
# Shape of array for priogrid_gid -2.0359359451579206: (80, 51)
# Shape of array for priogrid_gid -2.0358985034103902: (80, 51)
# Shape of array for priogrid_gid -2.0358610616628594: (80, 51)
# Shape of array for priogrid_gid -2.0358236199153286: (80, 51)
# Shape of array for priogrid_gid -2.0357861781677977: (80, 51)
# Shape of array for priogrid_gid -2.035748736420267: (80, 51)
# Shape of array for priogrid_gid -2.0357112946727365: (80, 51)
# Shape of array for priogrid_gid -2.0356738529252056: (80, 51)
# Shape of array for priogrid_gid -2.035636411177675: (80, 51)
# Shape of array for priogrid_gid -2.0099888141191085: (80, 51)
# Shape of array for priogrid_gid -2.0099513723715776: (80, 51)
# Shape of array for priogrid_gid -2.0099139306240468: (80, 51)
# Shape of array for priogrid_gid -2.009876488876516: (80, 51)
# Shape of array for priogrid_gid -2.0098390471289855: (80, 51)
# Shape of array for priogrid_gid -2.0098016053814547: (80, 51)
# Shape of array for priogrid_gid -2.009764163633924: (80, 51)
# Shape of array for priogrid_gid -2.009726721886393: (80, 51)
# Shape of array for priogrid_gid -2.009689280138862: (80, 51)
# Shape of array for priogrid_gid -2.0096518383913318: (80, 51)
# Shape of array for priogrid_gid -2.009614396643801: (80, 51)
# Shape of array for priogrid_gid -2.00957695489627: (80, 51)
# Shape of array for priogrid_gid -2.0095395131487392: (80, 51)
# Shape of array for priogrid_gid -2.0095020714012084: (80, 51)
# Shape of array for priogrid_gid -2.009464629653678: (80, 51)
# Shape of array for priogrid_gid -2.009427187906147: (80, 51)
# Shape of array for priogrid_gid -2.0093897461586163: (80, 51)
# Shape of array for priogrid_gid -2.0093523044110855: (80, 51)
# Shape of array for priogrid_gid -2.0093148626635546: (80, 51)
# Shape of array for priogrid_gid -2.0092774209160242: (80, 51)
# Shape of array for priogrid_gid -2.0092399791684934: (80, 51)
# Shape of array for priogrid_gid -2.0092025374209626: (80, 51)
# Shape of array for priogrid_gid -2.0091650956734317: (80, 51)
# Shape of array for priogrid_gid -2.009127653925901: (80, 51)
# Shape of array for priogrid_gid -2.0090902121783705: (80, 51)
# Shape of array for priogrid_gid -2.0090527704308396: (80, 51)
# Shape of array for priogrid_gid -2.009015328683309: (80, 51)
# Shape of array for priogrid_gid -2.008977886935778: (80, 51)
# Shape of array for priogrid_gid -2.008940445188247: (80, 51)
# Shape of array for priogrid_gid -2.0089030034407167: (80, 51)
# Shape of array for priogrid_gid -2.008865561693186: (80, 51)
# Shape of array for priogrid_gid -2.008828119945655: (80, 51)
# Shape of array for priogrid_gid -2.008790678198124: (80, 51)
# Shape of array for priogrid_gid -2.0087532364505933: (80, 51)
# Shape of array for priogrid_gid -2.008715794703063: (80, 51)
# Shape of array for priogrid_gid -2.008678352955532: (80, 51)
# Shape of array for priogrid_gid -1.9830681976444964: (80, 51)
# Shape of array for priogrid_gid -1.9830307558969655: (80, 51)
# Shape of array for priogrid_gid -1.982993314149435: (80, 51)
# Shape of array for priogrid_gid -1.982955872401904: (80, 51)
# Shape of array for priogrid_gid -1.9829184306543732: (80, 51)
# Shape of array for priogrid_gid -1.9828809889068426: (80, 51)
# Shape of array for priogrid_gid -1.9828435471593118: (80, 51)
# Shape of array for priogrid_gid -1.9828061054117812: (80, 51)
# Shape of array for priogrid_gid -1.9827686636642503: (80, 51)
# Shape of array for priogrid_gid -1.9827312219167195: (80, 51)
# Shape of array for priogrid_gid -1.9826937801691888: (80, 51)
# Shape of array for priogrid_gid -1.982656338421658: (80, 51)
# Shape of array for priogrid_gid -1.9826188966741274: (80, 51)
# Shape of array for priogrid_gid -1.9825814549265965: (80, 51)
# Shape of array for priogrid_gid -1.9825440131790657: (80, 51)
# Shape of array for priogrid_gid -1.982506571431535: (80, 51)
# Shape of array for priogrid_gid -1.9824691296840042: (80, 51)
# Shape of array for priogrid_gid -1.9824316879364736: (80, 51)
# Shape of array for priogrid_gid -1.9823942461889428: (80, 51)
# Shape of array for priogrid_gid -1.982356804441412: (80, 51)
# Shape of array for priogrid_gid -1.9823193626938813: (80, 51)
# Shape of array for priogrid_gid -1.9822819209463505: (80, 51)
# Shape of array for priogrid_gid -1.9822444791988199: (80, 51)
# Shape of array for priogrid_gid -1.982207037451289: (80, 51)
# Shape of array for priogrid_gid -1.9821695957037582: (80, 51)
# Shape of array for priogrid_gid -1.9821321539562275: (80, 51)
# Shape of array for priogrid_gid -1.9820947122086967: (80, 51)
# Shape of array for priogrid_gid -1.982057270461166: (80, 51)
# Shape of array for priogrid_gid -1.9820198287136352: (80, 51)
# Shape of array for priogrid_gid -1.9819823869661044: (80, 51)
# Shape of array for priogrid_gid -1.9819449452185738: (80, 51)
# Shape of array for priogrid_gid -1.981907503471043: (80, 51)
# Shape of array for priogrid_gid -1.981870061723512: (80, 51)
# Shape of array for priogrid_gid -1.9818326199759815: (80, 51)
# Shape of array for priogrid_gid -1.9817951782284506: (80, 51)
# Shape of array for priogrid_gid -1.98175773648092: (80, 51)
# Shape of array for priogrid_gid -1.9817202947333892: (80, 51)
# Shape of array for priogrid_gid -1.9561101394223535: (80, 51)
# Shape of array for priogrid_gid -1.9560726976748228: (80, 51)
# Shape of array for priogrid_gid -1.956035255927292: (80, 51)
# Shape of array for priogrid_gid -1.9559978141797614: (80, 51)
# Shape of array for priogrid_gid -1.9559603724322305: (80, 51)
# Shape of array for priogrid_gid -1.9559229306846997: (80, 51)
# Shape of array for priogrid_gid -1.955885488937169: (80, 51)
# Shape of array for priogrid_gid -1.9558480471896382: (80, 51)
# Shape of array for priogrid_gid -1.9558106054421076: (80, 51)
# Shape of array for priogrid_gid -1.9557731636945768: (80, 51)
# Shape of array for priogrid_gid -1.955735721947046: (80, 51)
# Shape of array for priogrid_gid -1.9556982801995153: (80, 51)
# Shape of array for priogrid_gid -1.9556608384519845: (80, 51)
# Shape of array for priogrid_gid -1.9556233967044538: (80, 51)
# Shape of array for priogrid_gid -1.955585954956923: (80, 51)
# Shape of array for priogrid_gid -1.9555485132093922: (80, 51)
# Shape of array for priogrid_gid -1.9555110714618615: (80, 51)
# Shape of array for priogrid_gid -1.9554736297143307: (80, 51)
# Shape of array for priogrid_gid -1.9554361879668: (80, 51)
# Shape of array for priogrid_gid -1.9553987462192692: (80, 51)
# Shape of array for priogrid_gid -1.9553613044717384: (80, 51)
# Shape of array for priogrid_gid -1.9553238627242078: (80, 51)
# Shape of array for priogrid_gid -1.955286420976677: (80, 51)
# Shape of array for priogrid_gid -1.9552489792291463: (80, 51)
# Shape of array for priogrid_gid -1.9552115374816155: (80, 51)
# Shape of array for priogrid_gid -1.9551740957340846: (80, 51)
# Shape of array for priogrid_gid -1.955136653986554: (80, 51)
# Shape of array for priogrid_gid -1.9550992122390232: (80, 51)
# Shape of array for priogrid_gid -1.9550617704914923: (80, 51)
# Shape of array for priogrid_gid -1.9550243287439617: (80, 51)
# Shape of array for priogrid_gid -1.9549868869964309: (80, 51)
# Shape of array for priogrid_gid -1.9549494452489002: (80, 51)
# Shape of array for priogrid_gid -1.9549120035013694: (80, 51)
# Shape of array for priogrid_gid -1.9548745617538386: (80, 51)
# Shape of array for priogrid_gid -1.954837120006308: (80, 51)
# Shape of array for priogrid_gid -1.954799678258777: (80, 51)
# Shape of array for priogrid_gid -1.9547622365112465: (80, 51)
# Shape of array for priogrid_gid -1.9538261928229776: (80, 51)
# Shape of array for priogrid_gid -1.9537887510754468: (80, 51)
# Shape of array for priogrid_gid -1.9291520812002108: (80, 51)
# Shape of array for priogrid_gid -1.92911463945268: (80, 51)
# Shape of array for priogrid_gid -1.9290771977051493: (80, 51)
# Shape of array for priogrid_gid -1.9290397559576185: (80, 51)
# Shape of array for priogrid_gid -1.9290023142100878: (80, 51)
# Shape of array for priogrid_gid -1.928964872462557: (80, 51)
# Shape of array for priogrid_gid -1.9289274307150261: (80, 51)
# Shape of array for priogrid_gid -1.9288899889674955: (80, 51)
# Shape of array for priogrid_gid -1.9288525472199647: (80, 51)
# Shape of array for priogrid_gid -1.928815105472434: (80, 51)
# Shape of array for priogrid_gid -1.9287776637249032: (80, 51)
# Shape of array for priogrid_gid -1.9287402219773724: (80, 51)
# Shape of array for priogrid_gid -1.9287027802298418: (80, 51)
# Shape of array for priogrid_gid -1.928665338482311: (80, 51)
# Shape of array for priogrid_gid -1.9286278967347803: (80, 51)
# Shape of array for priogrid_gid -1.9285904549872495: (80, 51)
# Shape of array for priogrid_gid -1.9285530132397186: (80, 51)
# Shape of array for priogrid_gid -1.928515571492188: (80, 51)
# Shape of array for priogrid_gid -1.9284781297446572: (80, 51)
# Shape of array for priogrid_gid -1.9284406879971263: (80, 51)
# Shape of array for priogrid_gid -1.9284032462495957: (80, 51)
# Shape of array for priogrid_gid -1.9283658045020649: (80, 51)
# Shape of array for priogrid_gid -1.9283283627545342: (80, 51)
# Shape of array for priogrid_gid -1.9282909210070034: (80, 51)
# Shape of array for priogrid_gid -1.9282534792594725: (80, 51)
# Shape of array for priogrid_gid -1.928216037511942: (80, 51)
# Shape of array for priogrid_gid -1.928178595764411: (80, 51)
# Shape of array for priogrid_gid -1.9281411540168805: (80, 51)
# Shape of array for priogrid_gid -1.9281037122693496: (80, 51)
# Shape of array for priogrid_gid -1.9280662705218188: (80, 51)
# Shape of array for priogrid_gid -1.9280288287742882: (80, 51)
# Shape of array for priogrid_gid -1.9279913870267573: (80, 51)
# Shape of array for priogrid_gid -1.9279539452792267: (80, 51)
# Shape of array for priogrid_gid -1.9279165035316959: (80, 51)
# Shape of array for priogrid_gid -1.927879061784165: (80, 51)
# Shape of array for priogrid_gid -1.9278416200366344: (80, 51)
# Shape of array for priogrid_gid -1.9278041782891036: (80, 51)
# Shape of array for priogrid_gid -1.927766736541573: (80, 51)
# Shape of array for priogrid_gid -1.927729294794042: (80, 51)
# Shape of array for priogrid_gid -1.9276918530465113: (80, 51)
# Shape of array for priogrid_gid -1.9269430180958962: (80, 51)
# Shape of array for priogrid_gid -1.9269055763483656: (80, 51)
# Shape of array for priogrid_gid -1.9268681346008347: (80, 51)
# Shape of array for priogrid_gid -1.926830692853304: (80, 51)
# Shape of array for priogrid_gid -1.9267932511057733: (80, 51)
# Shape of array for priogrid_gid -1.9267558093582424: (80, 51)
# Shape of array for priogrid_gid -1.9267183676107118: (80, 51)
# Shape of array for priogrid_gid -1.902194022978068: (80, 51)
# Shape of array for priogrid_gid -1.9021565812305372: (80, 51)
# Shape of array for priogrid_gid -1.9021191394830064: (80, 51)
# Shape of array for priogrid_gid -1.9020816977354758: (80, 51)
# Shape of array for priogrid_gid -1.902044255987945: (80, 51)
# Shape of array for priogrid_gid -1.9020068142404143: (80, 51)
# Shape of array for priogrid_gid -1.9019693724928834: (80, 51)
# Shape of array for priogrid_gid -1.9019319307453526: (80, 51)
# Shape of array for priogrid_gid -1.901894488997822: (80, 51)
# Shape of array for priogrid_gid -1.9018570472502911: (80, 51)
# Shape of array for priogrid_gid -1.9018196055027605: (80, 51)
# Shape of array for priogrid_gid -1.9017821637552297: (80, 51)
# Shape of array for priogrid_gid -1.9017447220076988: (80, 51)
# Shape of array for priogrid_gid -1.9017072802601682: (80, 51)
# Shape of array for priogrid_gid -1.9016698385126374: (80, 51)
# Shape of array for priogrid_gid -1.9016323967651065: (80, 51)
# Shape of array for priogrid_gid -1.901594955017576: (80, 51)
# Shape of array for priogrid_gid -1.901557513270045: (80, 51)
# Shape of array for priogrid_gid -1.9015200715225145: (80, 51)
# Shape of array for priogrid_gid -1.9014826297749836: (80, 51)
# Shape of array for priogrid_gid -1.9014451880274528: (80, 51)
# Shape of array for priogrid_gid -1.9014077462799222: (80, 51)
# Shape of array for priogrid_gid -1.9013703045323913: (80, 51)
# Shape of array for priogrid_gid -1.9013328627848607: (80, 51)
# Shape of array for priogrid_gid -1.9012954210373298: (80, 51)
# Shape of array for priogrid_gid -1.901257979289799: (80, 51)
# Shape of array for priogrid_gid -1.9012205375422684: (80, 51)
# Shape of array for priogrid_gid -1.9011830957947375: (80, 51)
# Shape of array for priogrid_gid -1.901145654047207: (80, 51)
# Shape of array for priogrid_gid -1.901108212299676: (80, 51)
# Shape of array for priogrid_gid -1.9010707705521452: (80, 51)
# Shape of array for priogrid_gid -1.9010333288046146: (80, 51)
# Shape of array for priogrid_gid -1.9009958870570838: (80, 51)
# Shape of array for priogrid_gid -1.9009584453095532: (80, 51)
# Shape of array for priogrid_gid -1.9009210035620223: (80, 51)
# Shape of array for priogrid_gid -1.9008835618144915: (80, 51)
# Shape of array for priogrid_gid -1.9008461200669609: (80, 51)
# Shape of array for priogrid_gid -1.90080867831943: (80, 51)
# Shape of array for priogrid_gid -1.9007712365718994: (80, 51)
# Shape of array for priogrid_gid -1.9007337948243685: (80, 51)
# Shape of array for priogrid_gid -1.9006963530768377: (80, 51)
# Shape of array for priogrid_gid -1.900658911329307: (80, 51)
# Shape of array for priogrid_gid -1.9000224016212843: (80, 51)
# Shape of array for priogrid_gid -1.8999849598737535: (80, 51)
# Shape of array for priogrid_gid -1.8999475181262226: (80, 51)
# Shape of array for priogrid_gid -1.899910076378692: (80, 51)
# Shape of array for priogrid_gid -1.8998726346311612: (80, 51)
# Shape of array for priogrid_gid -1.8998351928836306: (80, 51)
# Shape of array for priogrid_gid -1.8997977511360997: (80, 51)
# Shape of array for priogrid_gid -1.8997603093885689: (80, 51)
# Shape of array for priogrid_gid -1.875273406503456: (80, 51)
# Shape of array for priogrid_gid -1.8752359647559251: (80, 51)
# Shape of array for priogrid_gid -1.8751985230083945: (80, 51)
# Shape of array for priogrid_gid -1.8751610812608637: (80, 51)
# Shape of array for priogrid_gid -1.8751236395133328: (80, 51)
# Shape of array for priogrid_gid -1.8750861977658022: (80, 51)
# Shape of array for priogrid_gid -1.8750487560182714: (80, 51)
# Shape of array for priogrid_gid -1.8750113142707405: (80, 51)
# Shape of array for priogrid_gid -1.87497387252321: (80, 51)
# Shape of array for priogrid_gid -1.874936430775679: (80, 51)
# Shape of array for priogrid_gid -1.8748989890281484: (80, 51)
# Shape of array for priogrid_gid -1.8748615472806176: (80, 51)
# Shape of array for priogrid_gid -1.8748241055330868: (80, 51)
# Shape of array for priogrid_gid -1.8747866637855561: (80, 51)
# Shape of array for priogrid_gid -1.8747492220380253: (80, 51)
# Shape of array for priogrid_gid -1.8747117802904947: (80, 51)
# Shape of array for priogrid_gid -1.8746743385429638: (80, 51)
# Shape of array for priogrid_gid -1.874636896795433: (80, 51)
# Shape of array for priogrid_gid -1.8745994550479024: (80, 51)
# Shape of array for priogrid_gid -1.8745620133003715: (80, 51)
# Shape of array for priogrid_gid -1.874524571552841: (80, 51)
# Shape of array for priogrid_gid -1.87448712980531: (80, 51)
# Shape of array for priogrid_gid -1.8744496880577792: (80, 51)
# Shape of array for priogrid_gid -1.8744122463102486: (80, 51)
# Shape of array for priogrid_gid -1.8743748045627178: (80, 51)
# Shape of array for priogrid_gid -1.8743373628151871: (80, 51)
# Shape of array for priogrid_gid -1.8742999210676563: (80, 51)
# Shape of array for priogrid_gid -1.8742624793201255: (80, 51)
# Shape of array for priogrid_gid -1.8742250375725948: (80, 51)
# Shape of array for priogrid_gid -1.874187595825064: (80, 51)
# Shape of array for priogrid_gid -1.8741501540775334: (80, 51)
# Shape of array for priogrid_gid -1.8741127123300025: (80, 51)
# Shape of array for priogrid_gid -1.8740752705824717: (80, 51)
# Shape of array for priogrid_gid -1.874037828834941: (80, 51)
# Shape of array for priogrid_gid -1.8740003870874102: (80, 51)
# Shape of array for priogrid_gid -1.8739629453398796: (80, 51)
# Shape of array for priogrid_gid -1.8739255035923488: (80, 51)
# Shape of array for priogrid_gid -1.873888061844818: (80, 51)
# Shape of array for priogrid_gid -1.8738506200972873: (80, 51)
# Shape of array for priogrid_gid -1.8738131783497565: (80, 51)
# Shape of array for priogrid_gid -1.8737757366022258: (80, 51)
# Shape of array for priogrid_gid -1.873738294854695: (80, 51)
# Shape of array for priogrid_gid -1.8737008531071642: (80, 51)
# Shape of array for priogrid_gid -1.8730643433991414: (80, 51)
# Shape of array for priogrid_gid -1.8730269016516108: (80, 51)
# Shape of array for priogrid_gid -1.87298945990408: (80, 51)
# Shape of array for priogrid_gid -1.872952018156549: (80, 51)
# Shape of array for priogrid_gid -1.8729145764090185: (80, 51)
# Shape of array for priogrid_gid -1.8728771346614876: (80, 51)
# Shape of array for priogrid_gid -1.8728396929139568: (80, 51)
# Shape of array for priogrid_gid -1.8728022511664262: (80, 51)
# Shape of array for priogrid_gid -1.8727648094188953: (80, 51)
# Shape of array for priogrid_gid -1.848315348281313: (80, 51)
# Shape of array for priogrid_gid -1.8482779065337824: (80, 51)
# Shape of array for priogrid_gid -1.8482404647862516: (80, 51)
# Shape of array for priogrid_gid -1.8482030230387207: (80, 51)
# Shape of array for priogrid_gid -1.8481655812911901: (80, 51)
# Shape of array for priogrid_gid -1.8481281395436593: (80, 51)
# Shape of array for priogrid_gid -1.8480906977961287: (80, 51)
# Shape of array for priogrid_gid -1.8480532560485978: (80, 51)
# Shape of array for priogrid_gid -1.848015814301067: (80, 51)
# Shape of array for priogrid_gid -1.8479783725535364: (80, 51)
# Shape of array for priogrid_gid -1.8479409308060055: (80, 51)
# Shape of array for priogrid_gid -1.847903489058475: (80, 51)
# Shape of array for priogrid_gid -1.847866047310944: (80, 51)
# Shape of array for priogrid_gid -1.8478286055634132: (80, 51)
# Shape of array for priogrid_gid -1.8477911638158826: (80, 51)
# Shape of array for priogrid_gid -1.8477537220683518: (80, 51)
# Shape of array for priogrid_gid -1.8477162803208211: (80, 51)
# Shape of array for priogrid_gid -1.8476788385732903: (80, 51)
# Shape of array for priogrid_gid -1.8476413968257595: (80, 51)
# Shape of array for priogrid_gid -1.8476039550782288: (80, 51)
# Shape of array for priogrid_gid -1.847566513330698: (80, 51)
# Shape of array for priogrid_gid -1.8475290715831674: (80, 51)
# Shape of array for priogrid_gid -1.8474916298356365: (80, 51)
# Shape of array for priogrid_gid -1.8474541880881057: (80, 51)
# Shape of array for priogrid_gid -1.847416746340575: (80, 51)
# Shape of array for priogrid_gid -1.8473793045930442: (80, 51)
# Shape of array for priogrid_gid -1.8473418628455136: (80, 51)
# Shape of array for priogrid_gid -1.8473044210979828: (80, 51)
# Shape of array for priogrid_gid -1.847266979350452: (80, 51)
# Shape of array for priogrid_gid -1.8472295376029213: (80, 51)
# Shape of array for priogrid_gid -1.8471920958553905: (80, 51)
# Shape of array for priogrid_gid -1.8471546541078598: (80, 51)
# Shape of array for priogrid_gid -1.847117212360329: (80, 51)
# Shape of array for priogrid_gid -1.8470797706127982: (80, 51)
# Shape of array for priogrid_gid -1.8470423288652675: (80, 51)
# Shape of array for priogrid_gid -1.8470048871177367: (80, 51)
# Shape of array for priogrid_gid -1.846967445370206: (80, 51)
# Shape of array for priogrid_gid -1.8469300036226752: (80, 51)
# Shape of array for priogrid_gid -1.8468925618751444: (80, 51)
# Shape of array for priogrid_gid -1.8468551201276138: (80, 51)
# Shape of array for priogrid_gid -1.846817678380083: (80, 51)
# Shape of array for priogrid_gid -1.8467802366325523: (80, 51)
# Shape of array for priogrid_gid -1.8467427948850215: (80, 51)
# Shape of array for priogrid_gid -1.8467053531374906: (80, 51)
# Shape of array for priogrid_gid -1.8461062851769987: (80, 51)
# Shape of array for priogrid_gid -1.8460688434294679: (80, 51)
# Shape of array for priogrid_gid -1.846031401681937: (80, 51)
# Shape of array for priogrid_gid -1.8459939599344064: (80, 51)
# Shape of array for priogrid_gid -1.8459565181868756: (80, 51)
# Shape of array for priogrid_gid -1.845919076439345: (80, 51)
# Shape of array for priogrid_gid -1.845881634691814: (80, 51)
# Shape of array for priogrid_gid -1.8458441929442833: (80, 51)
# Shape of array for priogrid_gid -1.8458067511967526: (80, 51)
# Shape of array for priogrid_gid -1.8213572900591704: (80, 51)
# Shape of array for priogrid_gid -1.8213198483116395: (80, 51)
# Shape of array for priogrid_gid -1.821282406564109: (80, 51)
# Shape of array for priogrid_gid -1.821244964816578: (80, 51)
# Shape of array for priogrid_gid -1.8212075230690472: (80, 51)
# Shape of array for priogrid_gid -1.8211700813215166: (80, 51)
# Shape of array for priogrid_gid -1.8211326395739857: (80, 51)
# Shape of array for priogrid_gid -1.8210951978264551: (80, 51)
# Shape of array for priogrid_gid -1.8210577560789243: (80, 51)
# Shape of array for priogrid_gid -1.8210203143313934: (80, 51)
# Shape of array for priogrid_gid -1.8209828725838628: (80, 51)
# Shape of array for priogrid_gid -1.820945430836332: (80, 51)
# Shape of array for priogrid_gid -1.8209079890888014: (80, 51)
# Shape of array for priogrid_gid -1.8208705473412705: (80, 51)
# Shape of array for priogrid_gid -1.8208331055937397: (80, 51)
# Shape of array for priogrid_gid -1.820795663846209: (80, 51)
# ...
# Shape of array for priogrid_gid 1.5223405314272742: (80, 51)
# Shape of array for priogrid_gid 1.522377973174805: (80, 51)
# Shape of array for priogrid_gid 1.5224154149223357: (80, 51)
# Shape of array for priogrid_gid 1.5224528566698665: (80, 51)
# Shape of array for priogrid_gid 1.5224902984173971: (80, 51)
# Shape of array for priogrid_gid 1.522527740164928: (80, 51)
# Shape of array for priogrid_gid 1.5225651819124588: (80, 51)
# Shape of array for priogrid_gid 1.5226026236599894: (80, 51)
# Shape of array for priogrid_gid 1.5226400654075203: (80, 51)
# Shape of array for priogrid_gid 1.522677507155051: (80, 51)
# Shape of array for priogrid_gid 1.5227149489025817: (80, 51)
# Shape of array for priogrid_gid 1.5227523906501126: (80, 51)
# Shape of array for priogrid_gid 1.5227898323976432: (80, 51)
# Shape of array for priogrid_gid 1.522827274145174: (80, 51)
# Shape of array for priogrid_gid 1.5228647158927047: (80, 51)
# Shape of array for priogrid_gid 1.5229021576402355: (80, 51)
# Shape of array for priogrid_gid 1.5229395993877664: (80, 51)
# Shape of array for priogrid_gid 1.522977041135297: (80, 51)
# Shape of array for priogrid_gid 1.5230144828828278: (80, 51)
# Shape of array for priogrid_gid 1.5230519246303584: (80, 51)
# Shape of array for priogrid_gid 1.5230893663778893: (80, 51)
# Shape of array for priogrid_gid 1.5231268081254201: (80, 51)
# Shape of array for priogrid_gid 1.5231642498729507: (80, 51)
# Shape of array for priogrid_gid 1.5232016916204816: (80, 51)
# Shape of array for priogrid_gid 1.5232391333680122: (80, 51)
# Shape of array for priogrid_gid 1.523276575115543: (80, 51)
# Shape of array for priogrid_gid 1.5233140168630739: (80, 51)
# Shape of array for priogrid_gid 1.5233514586106045: (80, 51)
# Shape of array for priogrid_gid 1.5233889003581353: (80, 51)
# Shape of array for priogrid_gid 1.523426342105666: (80, 51)
# Shape of array for priogrid_gid 1.5234637838531968: (80, 51)
# Shape of array for priogrid_gid 1.5235012256007276: (80, 51)
# Shape of array for priogrid_gid 1.5235386673482583: (80, 51)
# Shape of array for priogrid_gid 1.523576109095789: (80, 51)
# Shape of array for priogrid_gid 1.5236135508433197: (80, 51)
# Shape of array for priogrid_gid 1.5236509925908506: (80, 51)
# Shape of array for priogrid_gid 1.5236884343383814: (80, 51)
# Shape of array for priogrid_gid 1.523725876085912: (80, 51)
# Shape of array for priogrid_gid 1.5237633178334429: (80, 51)
# Shape of array for priogrid_gid 1.5238007595809735: (80, 51)
# Shape of array for priogrid_gid 1.5238382013285043: (80, 51)
# Shape of array for priogrid_gid 1.5238756430760352: (80, 51)
# Shape of array for priogrid_gid 1.5239130848235658: (80, 51)
# Shape of array for priogrid_gid 1.5239505265710966: (80, 51)
# Shape of array for priogrid_gid 1.5239879683186273: (80, 51)
# Shape of array for priogrid_gid 1.524025410066158: (80, 51)
# Shape of array for priogrid_gid 1.549298589649417: (80, 51)
# Shape of array for priogrid_gid 1.5493360313969478: (80, 51)
# Shape of array for priogrid_gid 1.5493734731444786: (80, 51)
# Shape of array for priogrid_gid 1.5494109148920092: (80, 51)
# Shape of array for priogrid_gid 1.54944835663954: (80, 51)
# Shape of array for priogrid_gid 1.5494857983870707: (80, 51)
# Shape of array for priogrid_gid 1.5495232401346015: (80, 51)
# Shape of array for priogrid_gid 1.5495606818821324: (80, 51)
# Shape of array for priogrid_gid 1.549598123629663: (80, 51)
# Shape of array for priogrid_gid 1.5496355653771938: (80, 51)
# Shape of array for priogrid_gid 1.5496730071247244: (80, 51)
# Shape of array for priogrid_gid 1.5497104488722553: (80, 51)
# Shape of array for priogrid_gid 1.5497478906197861: (80, 51)
# Shape of array for priogrid_gid 1.5497853323673167: (80, 51)
# Shape of array for priogrid_gid 1.5498227741148476: (80, 51)
# Shape of array for priogrid_gid 1.5498602158623782: (80, 51)
# Shape of array for priogrid_gid 1.549897657609909: (80, 51)
# Shape of array for priogrid_gid 1.54993509935744: (80, 51)
# Shape of array for priogrid_gid 1.5499725411049705: (80, 51)
# Shape of array for priogrid_gid 1.5500099828525014: (80, 51)
# Shape of array for priogrid_gid 1.550047424600032: (80, 51)
# Shape of array for priogrid_gid 1.5500848663475628: (80, 51)
# Shape of array for priogrid_gid 1.5501223080950937: (80, 51)
# Shape of array for priogrid_gid 1.5501597498426243: (80, 51)
# Shape of array for priogrid_gid 1.5501971915901551: (80, 51)
# Shape of array for priogrid_gid 1.5502346333376857: (80, 51)
# Shape of array for priogrid_gid 1.5502720750852166: (80, 51)
# Shape of array for priogrid_gid 1.5503095168327474: (80, 51)
# Shape of array for priogrid_gid 1.550346958580278: (80, 51)
# Shape of array for priogrid_gid 1.5503844003278089: (80, 51)
# Shape of array for priogrid_gid 1.5504218420753395: (80, 51)
# Shape of array for priogrid_gid 1.5504592838228703: (80, 51)
# Shape of array for priogrid_gid 1.5504967255704012: (80, 51)
# Shape of array for priogrid_gid 1.5505341673179318: (80, 51)
# Shape of array for priogrid_gid 1.5505716090654627: (80, 51)
# Shape of array for priogrid_gid 1.5506090508129933: (80, 51)
# Shape of array for priogrid_gid 1.5506464925605241: (80, 51)
# Shape of array for priogrid_gid 1.550683934308055: (80, 51)
# Shape of array for priogrid_gid 1.5507213760555856: (80, 51)
# Shape of array for priogrid_gid 1.5508337012981779: (80, 51)
# Shape of array for priogrid_gid 1.5508711430457087: (80, 51)
# Shape of array for priogrid_gid 1.5509085847932393: (80, 51)
# Shape of array for priogrid_gid 1.5509460265407702: (80, 51)
# Shape of array for priogrid_gid 1.5762566478715598: (80, 51)
# Shape of array for priogrid_gid 1.5762940896190905: (80, 51)
# Shape of array for priogrid_gid 1.5763315313666213: (80, 51)
# Shape of array for priogrid_gid 1.5763689731141521: (80, 51)
# Shape of array for priogrid_gid 1.5764064148616828: (80, 51)
# Shape of array for priogrid_gid 1.5764438566092136: (80, 51)
# Shape of array for priogrid_gid 1.5764812983567442: (80, 51)
# Shape of array for priogrid_gid 1.576518740104275: (80, 51)
# Shape of array for priogrid_gid 1.576556181851806: (80, 51)
# Shape of array for priogrid_gid 1.5765936235993365: (80, 51)
# Shape of array for priogrid_gid 1.5766310653468674: (80, 51)
# Shape of array for priogrid_gid 1.576668507094398: (80, 51)
# Shape of array for priogrid_gid 1.5767059488419288: (80, 51)
# Shape of array for priogrid_gid 1.5767433905894597: (80, 51)
# Shape of array for priogrid_gid 1.5767808323369903: (80, 51)
# Shape of array for priogrid_gid 1.5768182740845211: (80, 51)
# Shape of array for priogrid_gid 1.5768557158320518: (80, 51)
# Shape of array for priogrid_gid 1.5768931575795826: (80, 51)
# Shape of array for priogrid_gid 1.5769305993271134: (80, 51)
# Shape of array for priogrid_gid 1.576968041074644: (80, 51)
# Shape of array for priogrid_gid 1.577005482822175: (80, 51)
# Shape of array for priogrid_gid 1.5770429245697055: (80, 51)
# Shape of array for priogrid_gid 1.5770803663172364: (80, 51)
# Shape of array for priogrid_gid 1.5771178080647672: (80, 51)
# Shape of array for priogrid_gid 1.5771552498122978: (80, 51)
# Shape of array for priogrid_gid 1.5771926915598287: (80, 51)
# Shape of array for priogrid_gid 1.5772301333073593: (80, 51)
# Shape of array for priogrid_gid 1.5772675750548901: (80, 51)
# Shape of array for priogrid_gid 1.577305016802421: (80, 51)
# Shape of array for priogrid_gid 1.5773424585499516: (80, 51)
# Shape of array for priogrid_gid 1.5773799002974824: (80, 51)
# Shape of array for priogrid_gid 1.577417342045013: (80, 51)
# Shape of array for priogrid_gid 1.577454783792544: (80, 51)
# Shape of array for priogrid_gid 1.5774922255400747: (80, 51)
# Shape of array for priogrid_gid 1.5775296672876054: (80, 51)
# Shape of array for priogrid_gid 1.5775671090351362: (80, 51)
# Shape of array for priogrid_gid 1.577604550782667: (80, 51)
# Shape of array for priogrid_gid 1.5776419925301977: (80, 51)
# Shape of array for priogrid_gid 1.5778292012678514: (80, 51)
# Shape of array for priogrid_gid 1.5778666430153823: (80, 51)
# Shape of array for priogrid_gid 1.5779040847629129: (80, 51)
# Shape of array for priogrid_gid 1.603177264346172: (80, 51)
# Shape of array for priogrid_gid 1.6032147060937025: (80, 51)
# Shape of array for priogrid_gid 1.6032521478412334: (80, 51)
# Shape of array for priogrid_gid 1.603289589588764: (80, 51)
# Shape of array for priogrid_gid 1.6033270313362948: (80, 51)
# Shape of array for priogrid_gid 1.6033644730838257: (80, 51)
# Shape of array for priogrid_gid 1.6034019148313563: (80, 51)
# Shape of array for priogrid_gid 1.6034393565788871: (80, 51)
# Shape of array for priogrid_gid 1.6034767983264178: (80, 51)
# Shape of array for priogrid_gid 1.6035142400739486: (80, 51)
# Shape of array for priogrid_gid 1.6035516818214794: (80, 51)
# Shape of array for priogrid_gid 1.60358912356901: (80, 51)
# Shape of array for priogrid_gid 1.603626565316541: (80, 51)
# Shape of array for priogrid_gid 1.6036640070640715: (80, 51)
# Shape of array for priogrid_gid 1.6037014488116024: (80, 51)
# Shape of array for priogrid_gid 1.6037388905591332: (80, 51)
# Shape of array for priogrid_gid 1.6037763323066638: (80, 51)
# Shape of array for priogrid_gid 1.6038137740541947: (80, 51)
# Shape of array for priogrid_gid 1.6038512158017253: (80, 51)
# Shape of array for priogrid_gid 1.6038886575492561: (80, 51)
# Shape of array for priogrid_gid 1.603926099296787: (80, 51)
# Shape of array for priogrid_gid 1.6039635410443176: (80, 51)
# Shape of array for priogrid_gid 1.6040009827918484: (80, 51)
# Shape of array for priogrid_gid 1.604038424539379: (80, 51)
# Shape of array for priogrid_gid 1.60407586628691: (80, 51)
# Shape of array for priogrid_gid 1.6041133080344407: (80, 51)
# Shape of array for priogrid_gid 1.6041507497819714: (80, 51)
# Shape of array for priogrid_gid 1.6041881915295022: (80, 51)
# Shape of array for priogrid_gid 1.604225633277033: (80, 51)
# Shape of array for priogrid_gid 1.6042630750245637: (80, 51)
# Shape of array for priogrid_gid 1.6043005167720945: (80, 51)
# Shape of array for priogrid_gid 1.6043379585196251: (80, 51)
# Shape of array for priogrid_gid 1.604375400267156: (80, 51)
# Shape of array for priogrid_gid 1.6044128420146868: (80, 51)
# Shape of array for priogrid_gid 1.6044502837622174: (80, 51)
# Shape of array for priogrid_gid 1.6044877255097483: (80, 51)
# Shape of array for priogrid_gid 1.604525167257279: (80, 51)
# Shape of array for priogrid_gid 1.6045626090048097: (80, 51)
# Shape of array for priogrid_gid 1.6301727643158455: (80, 51)
# Shape of array for priogrid_gid 1.630210206063376: (80, 51)
# Shape of array for priogrid_gid 1.630247647810907: (80, 51)
# Shape of array for priogrid_gid 1.6302850895584375: (80, 51)
# Shape of array for priogrid_gid 1.6303599730534992: (80, 51)
# Shape of array for priogrid_gid 1.6303974148010298: (80, 51)
# Shape of array for priogrid_gid 1.6304348565485607: (80, 51)
# Shape of array for priogrid_gid 1.6304722982960913: (80, 51)
# Shape of array for priogrid_gid 1.6305097400436221: (80, 51)
# Shape of array for priogrid_gid 1.630547181791153: (80, 51)
# Shape of array for priogrid_gid 1.6305846235386836: (80, 51)
# Shape of array for priogrid_gid 1.6306220652862145: (80, 51)
# Shape of array for priogrid_gid 1.630659507033745: (80, 51)
# Shape of array for priogrid_gid 1.630696948781276: (80, 51)
# Shape of array for priogrid_gid 1.6307343905288068: (80, 51)
# Shape of array for priogrid_gid 1.6307718322763374: (80, 51)
# Shape of array for priogrid_gid 1.6308092740238682: (80, 51)
# Shape of array for priogrid_gid 1.6308467157713988: (80, 51)
# Shape of array for priogrid_gid 1.6308841575189297: (80, 51)
# Shape of array for priogrid_gid 1.6309215992664605: (80, 51)
# Shape of array for priogrid_gid 1.6309590410139911: (80, 51)
# Shape of array for priogrid_gid 1.630996482761522: (80, 51)
# Shape of array for priogrid_gid 1.6310339245090528: (80, 51)
# Shape of array for priogrid_gid 1.6310713662565834: (80, 51)
# Shape of array for priogrid_gid 1.6311088080041143: (80, 51)
# Shape of array for priogrid_gid 1.631146249751645: (80, 51)
# Shape of array for priogrid_gid 1.6311836914991757: (80, 51)
# Shape of array for priogrid_gid 1.6312211332467066: (80, 51)
# Shape of array for priogrid_gid 1.6312585749942372: (80, 51)
# Shape of array for priogrid_gid 1.631296016741768: (80, 51)
# Shape of array for priogrid_gid 1.6313334584892987: (80, 51)
# Shape of array for priogrid_gid 1.6313709002368295: (80, 51)
# Shape of array for priogrid_gid 1.6314083419843604: (80, 51)
# Shape of array for priogrid_gid 1.631445783731891: (80, 51)
# Shape of array for priogrid_gid 1.6314832254794218: (80, 51)
# Shape of array for priogrid_gid 1.6571308225379882: (80, 51)
# Shape of array for priogrid_gid 1.657168264285519: (80, 51)
# Shape of array for priogrid_gid 1.6572057060330496: (80, 51)
# Shape of array for priogrid_gid 1.6572431477805805: (80, 51)
# Shape of array for priogrid_gid 1.657280589528111: (80, 51)
# Shape of array for priogrid_gid 1.657318031275642: (80, 51)
# Shape of array for priogrid_gid 1.6573554730231728: (80, 51)
# Shape of array for priogrid_gid 1.6573929147707034: (80, 51)
# Shape of array for priogrid_gid 1.6574303565182342: (80, 51)
# Shape of array for priogrid_gid 1.6574677982657648: (80, 51)
# Shape of array for priogrid_gid 1.6575052400132957: (80, 51)
# Shape of array for priogrid_gid 1.6575426817608265: (80, 51)
# Shape of array for priogrid_gid 1.6575801235083572: (80, 51)
# Shape of array for priogrid_gid 1.657617565255888: (80, 51)
# Shape of array for priogrid_gid 1.6576550070034188: (80, 51)
# Shape of array for priogrid_gid 1.6576924487509495: (80, 51)
# Shape of array for priogrid_gid 1.6577298904984803: (80, 51)
# Shape of array for priogrid_gid 1.657767332246011: (80, 51)
# Shape of array for priogrid_gid 1.6578047739935418: (80, 51)
# Shape of array for priogrid_gid 1.6578422157410726: (80, 51)
# Shape of array for priogrid_gid 1.6578796574886032: (80, 51)
# Shape of array for priogrid_gid 1.657917099236134: (80, 51)
# Shape of array for priogrid_gid 1.6579545409836647: (80, 51)
# Shape of array for priogrid_gid 1.6579919827311955: (80, 51)
# Shape of array for priogrid_gid 1.658066866226257: (80, 51)
# Shape of array for priogrid_gid 1.6581043079737878: (80, 51)
# Shape of array for priogrid_gid 1.6581417497213184: (80, 51)
# Shape of array for priogrid_gid 1.6581791914688493: (80, 51)
# Shape of array for priogrid_gid 1.6582166332163801: (80, 51)
# Shape of array for priogrid_gid 1.6582540749639108: (80, 51)
# Shape of array for priogrid_gid 1.6582915167114416: (80, 51)
# Shape of array for priogrid_gid 1.6583289584589722: (80, 51)
# Shape of array for priogrid_gid 1.658366400206503: (80, 51)
# Shape of array for priogrid_gid 1.658403841954034: (80, 51)
# Shape of array for priogrid_gid 1.6584412837015645: (80, 51)
# Shape of array for priogrid_gid 1.6840888807601309: (80, 51)
# Shape of array for priogrid_gid 1.6841263225076617: (80, 51)
# Shape of array for priogrid_gid 1.6841637642551925: (80, 51)
# Shape of array for priogrid_gid 1.6842012060027232: (80, 51)
# Shape of array for priogrid_gid 1.684238647750254: (80, 51)
# Shape of array for priogrid_gid 1.6845007399829692: (80, 51)
# Shape of array for priogrid_gid 1.6845381817305: (80, 51)
# Shape of array for priogrid_gid 1.6845756234780307: (80, 51)
# Shape of array for priogrid_gid 1.6846130652255615: (80, 51)
# Shape of array for priogrid_gid 1.6846505069730924: (80, 51)
# Shape of array for priogrid_gid 1.684687948720623: (80, 51)
# Shape of array for priogrid_gid 1.6847253904681538: (80, 51)
# Shape of array for priogrid_gid 1.6847628322156845: (80, 51)
# Shape of array for priogrid_gid 1.6848002739632153: (80, 51)
# Shape of array for priogrid_gid 1.6848377157107461: (80, 51)
# Shape of array for priogrid_gid 1.6852495749335843: (80, 51)
# Shape of array for priogrid_gid 1.6852870166811151: (80, 51)
# Shape of array for priogrid_gid 1.6853244584286458: (80, 51)
# Shape of array for priogrid_gid 1.7110843807298046: (80, 51)
# Shape of array for priogrid_gid 1.7111218224773352: (80, 51)
# Shape of array for priogrid_gid 1.711159264224866: (80, 51)
# Shape of array for priogrid_gid 1.7115711234477042: (80, 51)
# Shape of array for priogrid_gid 1.711608565195235: (80, 51)
# Shape of array for priogrid_gid 1.7116834486902965: (80, 51)
# Shape of array for priogrid_gid 1.7117208904378274: (80, 51)

# %%
data_ns, adj_matrix_ns, conv_layer_ns = create_graph_pyg_ns(df_filtered, num_neighbors=4, hidden_channels=64)

# %%
df_filtered
# Out:
#            ged_sb  decay_ged_ns_1  sptime_dist_k001_ged_ns
# 0       -0.026241       -0.165654                 4.738637  \
# 1       -0.026241       -0.165654                -0.475191
# 2       -0.026241       -0.165654                -0.419315
# 3       -0.026241       -0.165654                -0.333919
# 4       -0.026241       -0.165654                -0.494762
# ...           ...             ...                      ...
# 1048795 -0.026241       -0.165654                 2.320298
# 1048796 -0.026241       -0.165654                 0.995333
# 1048797 -0.026241       -0.165654                 0.908653
# 1048798 -0.026241       -0.165654                 0.767960
# 1048799 -0.026241       -0.165654                 0.716314
#
#          splag_1_decay_ged_sb_1  sptime_dist_k001_ged_os  wdi_nv_agr_totl_kd
# 0                     -0.371313                 9.639623           -0.368149  \
# 1                     -0.371299                 0.392014           -0.368149
# 2                     -0.371295                 0.420701           -0.368149
# 3                     -0.371299                 0.504226           -0.368149
# 4                     -0.371303                 0.315186           -0.368149
# ...                         ...                      ...                 ...
# 1048795               -0.371311                -0.447833           -0.624533
# 1048796               -0.371311                 0.284241            2.491172
# 1048797               -0.371311                 0.374058            2.491172
# 1048798               -0.371311                 0.695895            2.491172
# 1048799               -0.371311                 0.908511            2.491172
#
#          sptime_dist_k10_ged_ns  sptime_dist_k10_ged_os
# 0                      6.738254                6.532327  \
# 1                      4.768209                4.485963
# 2                      4.792157                4.459127
# 3                      4.816913                4.433556
# 4                      4.650759                4.457748
# ...                         ...                     ...
# 1048795                0.158557                1.087421
# 1048796               -0.470458                0.283821
# 1048797               -0.512859                0.220832
# 1048798               -0.584801                0.102800
# 1048799               -0.613292                0.048359
#
#          sptime_dist_k1_ged_ns  spei_48_detrend  ...  ged_sb_tlag_12
# 0                     6.400377         0.885765  ...       -0.028663  \
# 1                     4.577182         1.637610  ...       -0.028663
# 2                     4.558453         1.637610  ...       -0.028663
# 3                     4.540879         1.180225  ...       -0.028663
# 4                     4.549976         1.033693  ...       -0.028663
# ...                        ...              ...  ...             ...
# 1048795               0.405020         0.082860  ...       -0.028663
# 1048796              -0.273830         0.082860  ...       -0.028663
# 1048797              -0.316462         0.082860  ...       -0.028663
# 1048798              -0.385566         0.082860  ...       -0.028663
# 1048799              -0.410901         0.082860  ...       -0.028663
#
#          ged_sb_tlag_5  treelag_1_sb  count_moder_drought_prev10
# 0            -0.027348     -0.418114                   -0.891808  \
# 1            -0.027348     -0.341964                   -0.891808
# 2            -0.027348     -0.341295                    0.022680
# 3            -0.027348     -0.340648                    0.632338
# 4            -0.027348     -0.339685                   -0.891808
# ...                ...           ...                         ...
# 1048795      -0.027348      0.457276                   -0.891808
# 1048796      -0.027348      0.622447                   -0.891808
# 1048797      -0.027348      0.451083                   -0.891808
# 1048798      -0.027348      0.471825                   -0.891808
# 1048799      -0.027348      0.481474                   -0.891808
#
#          treelag_2_sb  ged_sb_tlag_10  tlag_12_harvarea_maincrops
# 0           -0.170367       -0.028344                   -0.388428  \
# 1           -0.167622       -0.028344                   -0.453037
# 2           -0.167596       -0.028344                   -0.068737
# 3           -0.167570       -0.028344                    0.081107
# 4           -0.167533       -0.028344                   -0.451336
# ...               ...             ...                         ...
# 1048795     -0.112974       -0.028344                   -0.491396
# 1048796     -0.087101       -0.028344                   -0.491396
# 1048797     -0.104159       -0.028344                   -0.491396
# 1048798     -0.100443       -0.028344                   -0.491396
# 1048799     -0.098751       -0.028344                   -0.491396
#
#          tlag_12_crop_sum       date  priogrid_gid
# 0               -0.333487 2016-01-01     -3.086626
# 1               -0.310987 2016-01-01     -2.441018
# 2                0.304655 2016-01-01     -2.440981
# 3                2.085527 2016-01-01     -2.440943
# 4               -0.337173 2016-01-01     -2.414135
# ...                   ...        ...           ...
# 1048795         -0.367803 2021-10-01      1.711159
# 1048796         -0.367803 2021-10-01      1.711571
# 1048797         -0.367803 2021-10-01      1.711609
# 1048798         -0.367803 2021-10-01      1.711683
# 1048799         -0.367803 2021-10-01      1.711721
#
# [1048800 rows x 52 columns]

# %%
class HybridGCNTransformer(nn.Module):
    def __init__(self, gcn_model, transformer_model, gcn_output_dim, transformer_output_dim, final_output_dim):
        super(HybridGCNTransformer, self).__init__()
        self.gcn = gcn_model
        self.transformer = transformer_model
        # Adjust the dimensions according to the last layer's output of GCN and Transformer
        self.fc1 = nn.Linear(gcn_output_dim + transformer_output_dim, 128)
        self.fc2 = nn.Linear(128, final_output_dim)
        self.dropout = nn.Dropout(0.1)
        self.relu = nn.ReLU()

    def forward(self, x_graph, adj_matrix, x_time, dates):
        # Forward pass through GCN
        gcn_output = self.gcn(x_graph, adj_matrix)
        # Assuming gcn_output and transformer_output are already in the proper shape to be concatenated
        # Forward pass through Transformer
        transformer_output = self.transformer(x_time, dates)
        # Concatenate the outputs from GCN and Transformer
        combined_features = torch.cat((gcn_output, transformer_output), dim=1)
        # Fully connected layers
        x = self.fc1(combined_features)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
class GraphDataset(Dataset):
    def __init__(self, data, adj_matrix):
        self.data = data
        self.adj_matrix = adj_matrix

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        gid = list(self.data.keys())[idx]
        # Exclude first column and last column
        
        target = np.array(self.data[gid][:, -1], dtype=np.float32)
        return torch.tensor(features), self.adj_matrix, torch.tensor(target)
    

class TransformerDataset(Dataset):
    def __init__(self, data, date_encodings):
        self.data = data
        self.date_encodings = date_encodings

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        gid = list(self.data.keys())[idx]
        features = np.array(self.data[gid][:, :-2], dtype=np.float32)  # Exclude the last two columns if last is target and second last is date
        target = np.array(self.data[gid][:, -1], dtype=np.float32)
        dates = self.date_encodings[gid]
        return torch.tensor(features), torch.tensor(dates), torch.tensor(target)

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x, dates):
        x = x + self.pe[:, :x.size(1)]
        return self.dropout(x)

class TemporalTransformerEncoder(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_layers, dim_feedforward=512, dropout=0.1):
        super(TemporalTransformerEncoder, self).__init__()
        self.input_embedding = nn.Linear(input_size, d_model // 2)
        self.pos_encoder = PositionalEncoding(d_model // 2, dropout=dropout)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model // 2, nhead=nhead // 2, dim_feedforward=dim_feedforward // 2, dropout=dropout, activation='gelu')
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        self.output_layer = nn.Linear(d_model // 2, 1)

    def forward(self, x, dates):
        x = self.input_embedding(x)
        x = self.pos_encoder(x, dates)
        x = self.transformer_encoder(x)
        output = self.output_layer(x)
        return output.squeeze(-1)
    
# Graph Convolution Layer
class GraphConvolution(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(GraphConvolution, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.weight = nn.Parameter(torch.Tensor(input_dim, output_dim))
        self.bias = nn.Parameter(torch.Tensor(output_dim))
        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_uniform_(self.weight)
        nn.init.zeros_(self.bias)

    def forward(self, x, adj):
        support = torch.matmul(x, self.weight)
        output = torch.sparse.mm(adj, support)
        output = output + self.bias
        return F.relu(output)

# GCN Model
class GCN(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, output_dim):
        super(GCN, self).__init__()
        self.gc1 = GraphConvolution(input_dim, hidden_dim1)
        self.gc2 = GraphConvolution(hidden_dim1, hidden_dim2)
        self.gc3 = GraphConvolution(hidden_dim2, output_dim)
        self.dropout = nn.Dropout(0.5)
        self.norm1 = nn.LayerNorm(hidden_dim1)
        self.norm2 = nn.LayerNorm(hidden_dim2)

    def forward(self, x, adj):
        x = self.gc1(x, adj)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.norm1(x)
        
        x = self.gc2(x, adj)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.norm2(x)
        
        x = self.gc3(x, adj)
        return x

# %%
import torch
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

# Custom Dataset that provides both graph and temporal data for each item
class HybridDataset(Dataset):
    def __init__(self, graph_data, temporal_data, temporal_date_encodings):
        self.graph_data = graph_data  # data for GCN
        self.temporal_data = temporal_data  # data for Transformer
        self.temporal_date_encodings = temporal_date_encodings

    def __len__(self):
        return len(self.graph_data)

    def __getitem__(self, idx):
        # Graph Data
        x_graph, adj_matrix, y_graph = self.graph_data[idx]
        
        # Temporal Data
        x_temporal, dates, y_temporal = self.temporal_data[idx]
        
        return x_graph, adj_matrix, x_temporal, dates, y_graph  # Assuming y_graph == y_temporal

# Example of DataLoader setup
graph_dataset = GraphDataset(data_ns, adj_matrix_ns)
temporal_dataset = TransformerDataset(transformer_input, date_encodings)
hybrid_dataset = HybridDataset(graph_dataset, temporal_dataset, date_encodings)
train_set, val_set = train_test_split(range(len(hybrid_dataset)), test_size=0.2, random_state=42)
train_loader = DataLoader([hybrid_dataset[i] for i in train_set], batch_size=64, shuffle=True)
val_loader = DataLoader([hybrid_dataset[i] for i in val_set], batch_size=64, shuffle=False)

# Initialize the hybrid model
gcn_model = GCN(input_dim=data_ns.x.size(1), hidden_dim1=256, hidden_dim2=256, output_dim=1)
transformer_model = TemporalTransformerEncoder(input_size=len(top_50_features), d_model=12, nhead=4, num_layers=16)
hybrid_model = HybridGCNTransformer(gcn_model, transformer_model, 256, 6, 1)
optimizer = torch.optim.Adam(hybrid_model.parameters(), lr=0.001)
criterion = nn.MSELoss()

train_losses = []
val_losses = []
val_r2_scores = []

def r_squared(y_true, y_pred):
    ss_res = ((y_true - y_pred) ** 2).sum()
    ss_tot = ((y_true - y_true.mean()) ** 2).sum()
    r2 = 1 - ss_res / ss_tot
    return r2.item()

for epoch in range(10):  # Number of epochs
    hybrid_model.train()
    total_train_loss = 0

    for x_graph, adj_matrix, x_temporal, dates, y in train_loader:
        optimizer.zero_grad()

        # Run the hybrid model forward pass
        output = hybrid_model(x_graph, adj_matrix, x_temporal, dates)
        
        # Compute loss
        loss = criterion(output, y)
        total_train_loss += loss.item()

        # Backpropagation
        loss.backward()
        optimizer.step()

    avg_train_loss = total_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)

    # Validation phase
    hybrid_model.eval()
    total_val_loss = 0
    total_r2 = 0
    with torch.no_grad():
        for x_graph, adj_matrix, x_temporal, dates, y in val_loader:
            output = hybrid_model(x_graph, adj_matrix, x_temporal, dates)
            loss = criterion(output, y)
            total_val_loss += loss.item()
            total_r2 += r_squared(y, output)  # Ensure r_squared is compatible with your data

    avg_val_loss = total_val_loss / len(val_loader)
    avg_r2 = total_r2 / len(val_loader)
    val_losses.append(avg_val_loss)
    val_r2_scores.append(avg_r2)

    print(f'Epoch: {epoch+1}, Training Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}, Val R^2: {avg_r2:.4f}')

    # # Optional: save the model if validation loss improves
    # if avg_val_loss < some_threshold:
    #     torch.save(hybrid_model.state_dict(), 'model_path.pth')
    #     print(f"Model saved at 'model_path.pth'")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 29
#      27 hybrid_dataset = HybridDataset(graph_dataset, temporal_dataset, date_encodings)
#      28 train_set, val_set = train_test_split(range(len(hybrid_dataset)), test_size=0.2, random_state=42)
# ---> 29 train_loader = DataLoader([hybrid_dataset[i] for i in train_set], batch_size=64, shuffle=True)
#      30 val_loader = DataLoader([hybrid_dataset[i] for i in val_set], batch_size=64, shuffle=False)
#      32 # Initialize the hybrid model
#
# Cell In[18], line 29, in <listcomp>(.0)
#      27 hybrid_dataset = HybridDataset(graph_dataset, temporal_dataset, date_encodings)
#      28 train_set, val_set = train_test_split(range(len(hybrid_dataset)), test_size=0.2, random_state=42)
# ---> 29 train_loader = DataLoader([hybrid_dataset[i] for i in train_set], batch_size=64, shuffle=True)
#      30 val_loader = DataLoader([hybrid_dataset[i] for i in val_set], batch_size=64, shuffle=False)
#      32 # Initialize the hybrid model
#
# Cell In[18], line 17, in HybridDataset.__getitem__(self, idx)
#      15 def __getitem__(self, idx):
#      16     # Graph Data
# ---> 17     x_graph, adj_matrix, y_graph = self.graph_data[idx]
#      19     # Temporal Data
#      20     x_temporal, dates, y_temporal = self.temporal_data[idx]
#
# Cell In[17], line 12, in GraphDataset.__getitem__(self, idx)
#      10 gid = list(self.data.keys())[idx]
#      11 # Exclude first column
# ---> 12 features = np.array(self.data[gid][:, 1:], dtype=np.float32)
#      13 # exclude the last column from features and convert it to float32
#      14 features = np.array(self.data[gid][:, :-1], dtype=np.float32)
#
# IndexError: too many indices for tensor of dimension 1
